# %% [markdown]
# # Obezite ve İnternet Kullanımı Arasındaki İlişki
#
# #### Gizem Kaya, Necdet Alperen Özil
#
#
#
# Amacımız 200 ülkeden alınan ve 1975-2016 yıllarını kapsayan verilerle, obez insanların toplam nüfus içindeki yüzdelik dilimlerini belirlemek ve yorumlamak. Bu iki değişken arasındaki ilişkinin doğru orantılı olduğu yönünde bir sonuç çıkmasını bekliyoruz. Çünkü internet kullanımının insanların hareketlerini azalttığını hatta insanların çoğu zaman hareket etmeye gerek bile duymadıklarını düşünüyoruz. Bu projede internet kullanımı arttıkça insanların daha fazla hareketsiz kalmasını ve hareketsizliğin obezite üzerindeki etkisini araştırdık.

# %% [markdown]
# ## İçerik
#
# [Problem](#problem)
# [Verinin Anlaşılması](#data_understanding)
# [Verilerin Hazırlanması](#data_preparation)
# [Modelleme](#modeling)
# [Değerlendirme](#evaluation)
# [Referanslar](#references)

# %% [markdown]
# ## Problem <a class="anchor" id="problem"></a>

# %% [markdown]
#    Dünyamızın büyüme ve gelişme hızı her geçen gün artmaktadır. Bu büyüme bize teknolojik açıdan, insan yaşamının kalitesini ve uzunluğunu artırmamız açısından imkan sağlıyor.
#
#    > Örneğin, internet üzerinden psikolojik yardım almak, evden ayrılması çok zor olan bir kişi için epey faydalı olabilir.
#
#    İnternetin, birçok sorunun çözümünde etkili olduğunu düşünsek de, bazen yan etkiler olabileceğini unutmamalıyız. İnternetin uzakları daha yakın hale getirmesi sadece sağlık alanında değil birçok iş alanında da hayatımızı kolaylaştırdı. Ancak bu sadece bir şeyleri yapmamızı kolaylaştırmakla ve hızlandırmakla kalmadı, aynı zamanda insanların bir şeylere ulaşmak için gösterdikleri çabayı da azalttı.
#
#    >Örneğin, uzaktan çalışan insanlar evlerinden hiç ayrılmadan başka ülkelere iş yapabilir, para kazanabilirler. Ya da bir arkadaşımızla görüşmek, onu görmek istediğimizde, yanına gitmeye gerek kalmadan o kişiyi görebiliriz.
#
#    Bunlar, internet sayesinde çaba harcamadan ayağımıza kadar gelen ayrıcalıklardır. Ancak, hareket etmenin insanın doğasında olduğunu, insan sağlığına fayda sağladığını ve kalp sağlığını koruyarak yaşamı uzattığını biliyoruz. Obezite, son 10 yıldır dünya gündeminde olan ve hareketsizlik sonucu ortaya çıkan hastalıklardan biridir. Obezitenin sebeplerinin hareketsizlik, aşırı yağlı veya karbonhidratlı yemekler ve çok fazla yemek yemek olduğunu biliyoruz. İnternet kullanımının boş zamanlarımızı sosyal medya veya uzaktan çalışma yoluyla doldurduğunu biliyoruz. Öyle ki bazen yemek yemek için bile yeterli zamanımız olmayabiliyor. Bu yüzden online siparişlerle fast food'a yöneliyoruz. Fast food yiyecekler harika görünse ve tadları mükemmel olsa da, bizi tam doyurmuyor ve tekrar acıkıyoruz. Besin değeri açısından yetersiz oldukları ve doyurmadıkları için tekrar yemek istiyoruz. Böylece internetin üzerimizdeki etkisini görüyoruz. Hem çok yemek yiyoruz hem de yüksek karbonhidratlı ve yağlı yemekler yiyoruz. Yemek yeme alışkanlıklarımızı bu şekilde devam ettirmek de bizleri obeziteye meyilli hale getiriyor.
#
#    Bu düşüncelerimiz ışığında, ülkelerdeki obez olan kişi sayısını internet kullanımı ile yıllara göre karşılaştırarak ikisi arasındaki bağlantıyı göstermeye çalıştık.

# %% [markdown]
# ## Verinin Anlaşılması<a class="anchor" id="data_understanding"></a>

# %% [markdown]
# Bu projede 3 farklı dataset kullanacağız. İlki internet kullanıcıları, ikincisi nüfus ve üçüncüsü obezite verileridir.

# %% [markdown]
# * *Internet Kullanıcıları*, The World Bank'den bulduğumuz İnternet Kullanıcıları, 264 ülkede internet kullanan toplam kişi sayısının yüzdesini 1960'dan 2019'a kadar her yıl için içeriyor. Verilere bakarsak, 2000'den önceki Internet Kullanıcıları data setindeki verilerin eksik olduğunu görüyoruz. Bu eksiklik, data setimizi ararken de dikkatimizi çekti, ancak internetin o zaman kullanılmadığını düşünürsek bu durumu makul bulduk.

# %% [markdown]
# *  *Nüfus*, 1960-2019 yılları arasında 264 ülkedeki nüfusu içermektedir. Nüfus data setine bakarsak, Nüfus ve İnternet Kullanıcıları data setinin benzer olduğunu görebiliriz. Çünkü data setlerin sağlandığı kaynaklar aynı. Bu, data setlerimizin üzerinde kolayca işlem yapabileceğimiz anlamına gelir.
#
#      Bazı ülkelerin çok az nüfusu olduğu için, internet kullanıcılarının yüzdesi o ülke hakkında güvenilir sonuçlar vermeyebilir. Örneğin, 2000 yılında nüfusu 100.000 olan bir ülkenin internet kullanıcılarının yüzdesi % 80'dir, bu ülkenin çok gelişmiş bir ülke olduğunu göstermez. 2016 yılına kadar 100.000'den fazla nüfusa sahip olamayan ülkelere baktığımızda, sık sık bu ülkelerin yeni kurulmuş ya da az gelişmiş olduklarını görüyoruz. Bu ülkeleri göz ardı edeceğiz çünkü işimize pek yaramayacaklarını düşünüyoruz.

# %% [markdown]
# * *Obezite*, Global Health Observatory Veri Deposu'nda bulduğumuz obezite data seti, 18 yaş üstü bireylerde cinsiyete göre ayırarak yaparak 1975'ten 2016'ya kadar olan yıllardaki 195 ülkenin obez nüfusunun gerçek nüfusa oranını göstermektedir. Data setler cinsiyete göre ayrılmamıştır 3 sütun bulunmaktadır. Toplam 3 sütundan her iki cinsiyet için de geçerli olan sütunu kullanacağız. Ancak bu data setin veri türü, vücut kitle endeksi (vke) 30 kg / m2 veya daha yüksek olan tanımlanmış popülasyonun yüzdesidir. Ve bu veriler, 1975'ten 2016'ya kadar vücut kitle endeksi, düşük kilolu, aşırı kilolu ve obezitede dünya çapındaki eğilimlerle hesaplanır: 128,9 milyon katılımcıyla 2416 nüfus tabanlı ölçüm çalışmasının birleştirilmiş analizi.

# %% [markdown]
# Gerekli kütüphanelerin yüklenmesi

# %%
# dataframe oluşturmak için

import pandas as pd

# modelleme ve değerlendirme için

import numpy as np
import sklearn as sk
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression 
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error 


# magic fonksiyon

# %matplotlib inline

# %% [markdown]
# ### Data setlerin elde edilmesi için csv uzantılı dosyaların okunması

# %% [markdown]
# Internet_Users.csv ve Population.csv kütüklerini okurken ilk 4 satırı göz ardı ettik. Çünkü bu satırlar tanımlayıcı görev görüyordu ve işimize yaramayacaktı.

# %%
# Indeks sütununu Country Name olarak vermek için index_col 0 olarak kullandık.

Internet_Users = pd.read_csv("Internet_Users.csv", skiprows=4, index_col=0)
Internet_Users.head(4)
# Out:
#              Country Code                                    Indicator Name  \
# Country Name
# Aruba                 ABW  Individuals using the Internet (% of population)
# Afghanistan           AFG  Individuals using the Internet (% of population)
# Angola                AGO  Individuals using the Internet (% of population)
# Albania               ALB  Individuals using the Internet (% of population)
#
#               Indicator Code  1960  1961  1962  1963  1964  1965  1966  ...  \
# Country Name                                                            ...
# Aruba         IT.NET.USER.ZS   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Afghanistan   IT.NET.USER.ZS   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Angola        IT.NET.USER.ZS   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Albania       IT.NET.USER.ZS   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#               2011       2012  2013   2014       2015       2016       2017  \
# Country Name
# Aruba         69.0  74.000000  78.9  83.78  88.661227  93.542454  97.170000
# Afghanistan    5.0   5.454545   5.9   7.00   8.260000  11.200000  13.500000
# Angola         3.1   6.500000   8.9  21.40  12.400000  13.000000  14.339079
# Albania       49.0  54.655959  57.2  60.10  63.252933  66.363445  71.847041
#
#               2018  2019  Unnamed: 64
# Country Name
# Aruba          NaN   NaN          NaN
# Afghanistan    NaN   NaN          NaN
# Angola         NaN   NaN          NaN
# Albania        NaN   NaN          NaN
#
# [4 rows x 64 columns]

# %%
Population = pd.read_csv("Population.csv", skiprows=4, index_col=0)
Population.head(4)
# Out:
#              Country Code     Indicator Name Indicator Code       1960  \
# Country Name
# Aruba                 ABW  Population, total    SP.POP.TOTL    54211.0
# Afghanistan           AFG  Population, total    SP.POP.TOTL  8996973.0
# Angola                AGO  Population, total    SP.POP.TOTL  5454933.0
# Albania               ALB  Population, total    SP.POP.TOTL  1608800.0
#
#                    1961       1962       1963       1964       1965  \
# Country Name
# Aruba           55438.0    56225.0    56695.0    57032.0    57360.0
# Afghanistan   9169410.0  9351441.0  9543205.0  9744781.0  9956320.0
# Angola        5531472.0  5608539.0  5679458.0  5735044.0  5770570.0
# Albania       1659800.0  1711319.0  1762621.0  1814135.0  1864791.0
#
#                     1966  ...        2011        2012        2013        2014  \
# Country Name              ...
# Aruba            57715.0  ...    102046.0    102560.0    103159.0    103774.0
# Afghanistan   10174836.0  ...  30117413.0  31161376.0  32269589.0  33370794.0
# Angola         5781214.0  ...  24220661.0  25107931.0  26015780.0  26941779.0
# Albania        1914573.0  ...   2905195.0   2900401.0   2895092.0   2889104.0
#
#                     2015        2016        2017        2018  2019  \
# Country Name
# Aruba           104341.0    104872.0    105366.0    105845.0   NaN
# Afghanistan   34413603.0  35383128.0  36296400.0  37172386.0   NaN
# Angola        27884381.0  28842484.0  29816748.0  30809762.0   NaN
# Albania        2880703.0   2876101.0   2873457.0   2866376.0   NaN
#
#               Unnamed: 64
# Country Name
# Aruba                 NaN
# Afghanistan           NaN
# Angola                NaN
# Albania               NaN
#
# [4 rows x 64 columns]

# %%
Obesity = pd.read_csv("Obesity.csv", index_col=0)
Obesity.head(4)
# Out:
#                                                           2016  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                             Both sexes
# Afghanistan                                      5.5 [3.4-8.1]
#
#                                                         2016.1  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                                   Male
# Afghanistan                                      3.2 [1.3-6.4]
#
#                                                         2016.2  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                                 Female
# Afghanistan                                     7.6 [4.3-12.4]
#
#                                                           2015  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                             Both sexes
# Afghanistan                                      5.2 [3.3-7.7]
#
#                                                         2015.1  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                                   Male
# Afghanistan                                      3.0 [1.3-6.0]
#
#                                                         2015.2  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                                 Female
# Afghanistan                                     7.3 [4.1-11.8]
#
#                                                           2014  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                             Both sexes
# Afghanistan                                      4.9 [3.1-7.3]
#
#                                                         2014.1  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                                   Male
# Afghanistan                                      2.8 [1.2-5.6]
#
#                                                         2014.2  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                                 Female
# Afghanistan                                     7.0 [4.0-11.3]
#
#                                                           2013  ...  \
# NaN          Prevalence of obesity among adults, BMI &Great...  ...
# NaN                                                 18+  years  ...
# Country                                             Both sexes  ...
# Afghanistan                                      4.7 [2.9-6.9]  ...
#
#                                                         1978.2  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                                 Female
# Afghanistan                                      0.9 [0.3-2.2]
#
#                                                           1977  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                             Both sexes
# Afghanistan                                      0.6 [0.2-1.2]
#
#                                                         1977.1  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                                   Male
# Afghanistan                                      0.2 [0.0-0.7]
#
#                                                         1977.2  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                                 Female
# Afghanistan                                      0.9 [0.3-2.1]
#
#                                                           1976  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                             Both sexes
# Afghanistan                                      0.5 [0.2-1.1]
#
#                                                         1976.1  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                                   Male
# Afghanistan                                      0.2 [0.0-0.7]
#
#                                                         1976.2  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                                 Female
# Afghanistan                                      0.8 [0.2-2.0]
#
#                                                           1975  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                             Both sexes
# Afghanistan                                      0.5 [0.2-1.1]
#
#                                                         1975.1  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                                   Male
# Afghanistan                                      0.2 [0.0-0.6]
#
#                                                         1975.2
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                                 Female
# Afghanistan                                      0.8 [0.2-2.0]
#
# [4 rows x 126 columns]

# %% [markdown]
# Internet_Users ve Population veri çerçevelerinin sütun türlerine bakarsak, baştaki 3 sütun hariç hepsinin float veri tipinde olduğunu görebiliriz.

# %%
print("Internet Users: \n", Internet_Users.dtypes)
print("\nPopulation: \n", Population.dtypes)
# Out:
# Internet Users:
#  Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
# 1961              float64
#                    ...
# 2016              float64
# 2017              float64
# 2018              float64
# 2019              float64
# Unnamed: 64       float64
# Length: 64, dtype: object
#
# Population:
#  Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
# 1961              float64
#                    ...
# 2016              float64
# 2017              float64
# 2018              float64
# 2019              float64
# Unnamed: 64       float64
# Length: 64, dtype: object

# %% [markdown]
# Obezite veri çerçevesinin sütun türlerine bakarsak, hepsinin nesne olduğunu görebiliriz çünkü iç sütunları vardır.

# %%
print("Obesity: \n", Obesity.dtypes)
# Out:
# Obesity:
#  2016      object
# 2016.1    object
# 2016.2    object
# 2015      object
# 2015.1    object
#            ...
# 1976.1    object
# 1976.2    object
# 1975      object
# 1975.1    object
# 1975.2    object
# Length: 126, dtype: object

# %% [markdown]
# Veri setlerinin içeriklerini daha iyi anlayabilmek için .describe(include = 'all') methodunu kullanırız.

# %%
print("Internet Users: \n", Internet_Users.describe(include = 'all'))
print("\nPopulation: \n", Population.describe(include = 'all'))
print("Obesity: \n", Obesity.describe(include = 'all'))
# Out:
# Internet Users:
#         Country Code                                    Indicator Name  \
# count           264                                               264
# unique          264                                                 1
# top             HKG  Individuals using the Internet (% of population)
# freq              1                                               264
# mean            NaN                                               NaN
# std             NaN                                               NaN
# min             NaN                                               NaN
# 25%             NaN                                               NaN
# 50%             NaN                                               NaN
# 75%             NaN                                               NaN
# max             NaN                                               NaN
#
#         Indicator Code  1960  1961  1962  1963  1964  1965  1966  ...  \
# count              264   7.0   0.0   0.0   0.0   0.0   7.0   0.0  ...
# unique               1   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# top     IT.NET.USER.ZS   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# freq               264   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# mean               NaN   0.0   NaN   NaN   NaN   NaN   0.0   NaN  ...
# std                NaN   0.0   NaN   NaN   NaN   NaN   0.0   NaN  ...
# min                NaN   0.0   NaN   NaN   NaN   NaN   0.0   NaN  ...
# 25%                NaN   0.0   NaN   NaN   NaN   NaN   0.0   NaN  ...
# 50%                NaN   0.0   NaN   NaN   NaN   NaN   0.0   NaN  ...
# 75%                NaN   0.0   NaN   NaN   NaN   NaN   0.0   NaN  ...
# max                NaN   0.0   NaN   NaN   NaN   NaN   0.0   NaN  ...
#
#               2011        2012        2013        2014        2015  \
# count   252.000000  249.000000  248.000000  247.000000  248.000000
# unique         NaN         NaN         NaN         NaN         NaN
# top            NaN         NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN         NaN
# mean     35.798565   38.761338   41.398580   44.289545   47.334178
# std      26.791900   27.490801   27.921178   27.727018   27.316139
# min       0.000000    0.000000    0.900000    0.990000    1.083733
# 25%      10.052500   12.500000   14.985000   17.742866   21.624376
# 50%      32.605579   36.082406   39.458210   42.061803   46.142268
# 75%      56.175000   61.534159   65.413700   68.315000   70.888467
# max      94.819687   96.209800   96.546800   98.160000   98.323610
#
#               2016        2017       2018  2019  Unnamed: 64
# count   250.000000  253.000000  96.000000   0.0          0.0
# unique         NaN         NaN        NaN   NaN          NaN
# top            NaN         NaN        NaN   NaN          NaN
# freq           NaN         NaN        NaN   NaN          NaN
# mean     50.030211   54.180959  73.284807   NaN          NaN
# std      27.904962   26.941966  18.383989   NaN          NaN
# min       1.177119    1.308907   5.250488   NaN          NaN
# 25%      23.347229   30.099184  64.798402   NaN          NaN
# 50%      52.572268   57.272244  75.147314   NaN          NaN
# 75%      74.806388   77.615257  84.455762   NaN          NaN
# max      98.240016  100.000000  99.652849   NaN          NaN
#
# [11 rows x 64 columns]
#
# Population:
#         Country Code     Indicator Name Indicator Code          1960  \
# count           264                264            264  2.600000e+02
# unique          264                  1              1           NaN
# top             HKG  Population, total    SP.POP.TOTL           NaN
# freq              1                264            264           NaN
# mean            NaN                NaN            NaN  1.180719e+08
# std             NaN                NaN            NaN  3.729676e+08
# min             NaN                NaN            NaN  3.893000e+03
# 25%             NaN                NaN            NaN  5.022908e+05
# 50%             NaN                NaN            NaN  3.658470e+06
# 75%             NaN                NaN            NaN  2.532671e+07
# max             NaN                NaN            NaN  3.032020e+09
#
#                 1961          1962          1963          1964          1965  \
# count   2.600000e+02  2.600000e+02  2.600000e+02  2.600000e+02  2.600000e+02
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    1.196571e+08  1.217754e+08  1.244116e+08  1.270684e+08  1.297908e+08
# std     3.774364e+08  3.840035e+08  3.925626e+08  4.011646e+08  4.100026e+08
# min     3.989000e+03  4.076000e+03  4.183000e+03  4.308000e+03  4.468000e+03
# 25%     5.109635e+05  5.206552e+05  5.311588e+05  5.421285e+05  5.533358e+05
# 50%     3.738358e+06  3.821016e+06  3.926268e+06  4.051891e+06  4.180652e+06
# 75%     2.611452e+07  2.690411e+07  2.766416e+07  2.839934e+07  2.913676e+07
# max     3.073078e+09  3.126066e+09  3.191186e+09  3.256700e+09  3.323624e+09
#
#                 1966  ...          2011          2012          2013  \
# count   2.600000e+02  ...  2.630000e+02  2.620000e+02  2.620000e+02
# unique           NaN  ...           NaN           NaN           NaN
# top              NaN  ...           NaN           NaN           NaN
# freq             NaN  ...           NaN           NaN           NaN
# mean    1.326579e+08  ...  2.811558e+08  2.857988e+08  2.894321e+08
# std     4.194078e+08  ...  8.926490e+08  9.048832e+08  9.157037e+08
# min     4.685000e+03  ...  1.005700e+04  1.027900e+04  1.082100e+04
# 25%     5.647510e+05  ...  1.449584e+06  1.409858e+06  1.427339e+06
# 50%     4.275565e+06  ...  9.460830e+06  9.624311e+06  9.746730e+06
# 75%     2.988608e+07  ...  5.149739e+07  5.247893e+07  5.323004e+07
# max     3.393699e+09  ...  7.004011e+09  7.086994e+09  7.170962e+09
#
#                 2014          2015          2016          2017          2018  \
# count   2.620000e+02  2.620000e+02  2.620000e+02  2.620000e+02  2.620000e+02
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    2.930987e+08  2.967799e+08  3.004928e+08  3.041979e+08  3.078444e+08
# std     9.265991e+08  9.375200e+08  9.485235e+08  9.595168e+08  9.702601e+08
# min     1.097200e+04  1.109900e+04  1.122500e+04  1.137000e+04  1.150800e+04
# 25%     1.444866e+06  1.463189e+06  1.514952e+06  1.577592e+06  1.638404e+06
# 50%     9.855382e+06  1.000153e+07  1.012427e+07  1.017900e+07  1.022952e+07
# 75%     5.397970e+07  5.470996e+07  5.541544e+07  5.641631e+07  5.741430e+07
# max     7.255654e+09  7.340548e+09  7.426103e+09  7.510990e+09  7.594270e+09
#
#         2019  Unnamed: 64
# count    0.0          0.0
# unique   NaN          NaN
# top      NaN          NaN
# freq     NaN          NaN
# mean     NaN          NaN
# std      NaN          NaN
# min      NaN          NaN
# 25%      NaN          NaN
# 50%      NaN          NaN
# 75%      NaN          NaN
# max      NaN          NaN
#
# [11 rows x 64 columns]
# Obesity:
#             2016   2016.1   2016.2     2015   2015.1   2015.2     2014  \
# count       198      198      198      198      198      198      198
# unique      192      195      195      194      194      195      194
# top     No data  No data  No data  No data  No data  No data  No data
# freq          4        4        4        4        4        4        4
#
#          2014.1   2014.2     2013  ...   1978.2     1977         1977.1  \
# count       198      198      198  ...      198      198            198
# unique      193      194      195  ...      192      184            164
# top     No data  No data  No data  ...  No data  No data  0.2 [0.0-0.7]
# freq          4        4        4  ...        4        4              6
#
#          1977.2     1976         1976.1   1976.2           1975  \
# count       198      198            198      198            198
# unique      185      183            161      190            177
# top     No data  No data  0.2 [0.0-0.7]  No data  0.9 [0.4-1.8]
# freq          4        4              7        4              4
#
#                1975.1   1975.2
# count             198      198
# unique            155      185
# top     0.4 [0.1-1.2]  No data
# freq                7        4
#
# [4 rows x 126 columns]

# %% [markdown]
# # Verilerin Hazırlanması<a class="anchor" id="data_preparation"></a>

# %% [markdown]
# ### Öznitelik Seçimi

# %% [markdown]
# Öznitelik seçimini yapabilmek için dataframe'i incelerken, 'Country Code', 'Indicator Name', 'Indicator Code' sütunlarının çalışmamızla alakalı olmadığını görüyoruz. Bu yüzden bu sütunlar atılmalıdır.

# %%
Internet_Users.drop([ 'Country Code', 'Indicator Name', 'Indicator Code'], axis=1, inplace = True) 

# axis 1 satırları değil sütunları kaldırdığımız anlamına gelmektedir.

# %% [markdown]
# Internet_Users data frame'inde yaptığımız gibi, öznitelik seçimini yapabilmek için Population data frame'ini incelerken, 'Country Code', 'Indicator Name', 'Indicator Code' sütunlarının çalışmamızla alakalı olmadığını görüyoruz. Bu yüzden bu sütunlar atılmalıdır.

# %%
Population.drop(['Country Code', 'Indicator Name', 'Indicator Code'], axis=1, inplace = True) 

# axis 1 satırları değil sütunları kaldırdığımız anlamına gelmektedir.

# %% [markdown]
# Elimizdeki dataya bakarak şunları söyleyebiliriz:
#
# Internet_Users ve Population data setimiz 1960-2019 yılları arasındaki tüm verileri içermektedir. Bununla birlikte, Obezite data setimiz 1975-2016 verilerini içermektedir. Bu nedenle, 2019 ve 2018 verilerinin çoğu eksik olduğundan, bu sütunların silinmesinde herhangi bir sakınca yoktur. Ayrıca, her üç data setinde de ortak olan yıllar üzerinde çalışmalarımıza devam etmemiz gerektiğinden, kesişimlerinin dışındaki yılları Internet_Users ve Population data setlerinden sileriz.

# %%
columns_should_dropped_list = ['1960','1961','1962','1963','1964','1965',
                               '1966','1967','1968','1969','1970','1971',
                               '1972','1973','1973','1974','2017','2018','2019','Unnamed: 64']



Internet_Users.drop(columns_should_dropped_list, axis=1, inplace = True)
Population.drop(columns_should_dropped_list, axis=1, inplace = True)

Internet_Users.head()
# Out:
#               1975  1976  1977  1978  1979  1980  1981  1982  1983  1984  ...  \
# Country Name                                                              ...
# Aruba          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Afghanistan    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Angola         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Albania        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Andorra        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#                    2007   2008   2009  2010  2011       2012  2013   2014  \
# Country Name
# Aruba         30.900000  52.00  58.00  62.0  69.0  74.000000  78.9  83.78
# Afghanistan    1.900000   1.84   3.55   4.0   5.0   5.454545   5.9   7.00
# Angola         1.700000   1.90   2.30   2.8   3.1   6.500000   8.9  21.40
# Albania       15.036115  23.86  41.20  45.0  49.0  54.655959  57.2  60.10
# Andorra       70.870000  70.04  78.53  81.0  81.0  86.434425  94.0  95.90
#
#                    2015       2016
# Country Name
# Aruba         88.661227  93.542454
# Afghanistan    8.260000  11.200000
# Angola        12.400000  13.000000
# Albania       63.252933  66.363445
# Andorra       96.910000  97.930637
#
# [5 rows x 42 columns]

# %%
Obesity.head(4)
# Out:
#                                                           2016  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                             Both sexes
# Afghanistan                                      5.5 [3.4-8.1]
#
#                                                         2016.1  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                                   Male
# Afghanistan                                      3.2 [1.3-6.4]
#
#                                                         2016.2  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                                 Female
# Afghanistan                                     7.6 [4.3-12.4]
#
#                                                           2015  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                             Both sexes
# Afghanistan                                      5.2 [3.3-7.7]
#
#                                                         2015.1  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                                   Male
# Afghanistan                                      3.0 [1.3-6.0]
#
#                                                         2015.2  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                                 Female
# Afghanistan                                     7.3 [4.1-11.8]
#
#                                                           2014  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                             Both sexes
# Afghanistan                                      4.9 [3.1-7.3]
#
#                                                         2014.1  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                                   Male
# Afghanistan                                      2.8 [1.2-5.6]
#
#                                                         2014.2  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                                 Female
# Afghanistan                                     7.0 [4.0-11.3]
#
#                                                           2013  ...  \
# NaN          Prevalence of obesity among adults, BMI &Great...  ...
# NaN                                                 18+  years  ...
# Country                                             Both sexes  ...
# Afghanistan                                      4.7 [2.9-6.9]  ...
#
#                                                         1978.2  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                                 Female
# Afghanistan                                      0.9 [0.3-2.2]
#
#                                                           1977  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                             Both sexes
# Afghanistan                                      0.6 [0.2-1.2]
#
#                                                         1977.1  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                                   Male
# Afghanistan                                      0.2 [0.0-0.7]
#
#                                                         1977.2  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                                 Female
# Afghanistan                                      0.9 [0.3-2.1]
#
#                                                           1976  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                             Both sexes
# Afghanistan                                      0.5 [0.2-1.1]
#
#                                                         1976.1  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                                   Male
# Afghanistan                                      0.2 [0.0-0.7]
#
#                                                         1976.2  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                                 Female
# Afghanistan                                      0.8 [0.2-2.0]
#
#                                                           1975  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                             Both sexes
# Afghanistan                                      0.5 [0.2-1.1]
#
#                                                         1975.1  \
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                                   Male
# Afghanistan                                      0.2 [0.0-0.6]
#
#                                                         1975.2
# NaN          Prevalence of obesity among adults, BMI &Great...
# NaN                                                 18+  years
# Country                                                 Female
# Afghanistan                                      0.8 [0.2-2.0]
#
# [4 rows x 126 columns]

# %% [markdown]
# Görüldüğü üzere, data frame'in ilk 3 satırında işe yarar veri yoktur. Yani, Obezite data frame'inin hazırlanmasının ilk adımı baştaki 3 satırdan kurtulmaktır.

# %%
Obesity = Obesity.iloc[3:, :]

# set index column's name as the other dataframe's index names.
Obesity.index.name = 'Country Name'
Obesity.head(2)
# Out:
#                           2016            2016.1            2016.2  \
# Country Name
# Afghanistan      5.5 [3.4-8.1]     3.2 [1.3-6.4]    7.6 [4.3-12.4]
# Albania       21.7 [17.0-26.7]  21.6 [14.8-29.0]  21.8 [15.3-28.9]
#
#                           2015            2015.1            2015.2  \
# Country Name
# Afghanistan      5.2 [3.3-7.7]     3.0 [1.3-6.0]    7.3 [4.1-11.8]
# Albania       21.1 [16.6-26.0]  20.9 [14.4-28.1]  21.3 [15.1-28.1]
#
#                           2014            2014.1            2014.2  \
# Country Name
# Afghanistan      4.9 [3.1-7.3]     2.8 [1.2-5.6]    7.0 [4.0-11.3]
# Albania       20.5 [16.2-25.1]  20.2 [13.9-27.3]  20.8 [14.9-27.4]
#
#                           2013  ...          1978.2            1977  \
# Country Name                    ...
# Afghanistan      4.7 [2.9-6.9]  ...   0.9 [0.3-2.2]   0.6 [0.2-1.2]
# Albania       19.9 [15.7-24.4]  ...  9.1 [4.6-15.5]  6.8 [4.0-10.7]
#
#                      1977.1          1977.2            1976         1976.1  \
# Country Name
# Afghanistan   0.2 [0.0-0.7]   0.9 [0.3-2.1]   0.5 [0.2-1.1]  0.2 [0.0-0.7]
# Albania       4.8 [2.0-9.3]  8.9 [4.3-15.4]  6.7 [3.8-10.6]  4.6 [1.8-9.2]
#
#                       1976.2            1975         1975.1          1975.2
# Country Name
# Afghanistan    0.8 [0.2-2.0]   0.5 [0.2-1.1]  0.2 [0.0-0.6]   0.8 [0.2-2.0]
# Albania       8.8 [4.1-15.4]  6.5 [3.6-10.5]  4.4 [1.7-9.2]  8.6 [3.9-15.4]
#
# [2 rows x 126 columns]

# %% [markdown]
# Sütunlara bakarsak, yılların yanındaki noktadan sonraki sayıları görürüz. Bu sayılar cinsiyetleri belirtmek içindir.
# Yanlarında sayı olmayan yıllar, her iki cinsiyeti de temsil eder. Yılda .1 varsa, bu sütunların erkek verilerine sahip olduğu anlamına gelir. Yılda .2 varsa, bu sütunların kadın verilerine sahip olduğu anlamına gelir.

# %% [markdown]
# Verileri daha net görebilmek için köşeli parantez içinde verilen detaylardan kurtulduk.

# %%
for column in Obesity:
    Obesity[column] = Obesity[column].astype(str).str[:4].astype(np.str)
    
Obesity.head(2)
# Out:
#               2016 2016.1 2016.2  2015 2015.1 2015.2  2014 2014.1 2014.2  \
# Country Name
# Afghanistan   5.5    3.2    7.6   5.2    3.0    7.3   4.9    2.8    7.0
# Albania       21.7   21.6   21.8  21.1   20.9   21.3  20.5   20.2   20.8
#
#               2013  ... 1978.2  1977 1977.1 1977.2  1976 1976.1 1976.2  1975  \
# Country Name        ...
# Afghanistan   4.7   ...   0.9   0.6    0.2    0.9   0.5    0.2    0.8   0.5
# Albania       19.9  ...   9.1   6.8    4.8    8.9   6.7    4.6    8.8   6.5
#
#              1975.1 1975.2
# Country Name
# Afghanistan    0.2    0.8
# Albania        4.4    8.6
#
# [2 rows x 126 columns]

# %%
Obesity.describe(include = 'all')
# Out:
#         2016 2016.1 2016.2  2015 2015.1 2015.2  2014 2014.1 2014.2  2013  ...  \
# count    195    195    195   195    195    195   195    195    195   195  ...
# unique   144    137    153   153    140    151   144    135    152   139  ...
# top     No d   24.2   No d  No d   No d   No d  19.2   4.1    No d  21.1  ...
# freq       4      4      4     4      4      4     4      5      4     4  ...
#
#        1978.2  1977 1977.1 1977.2  1976 1976.1 1976.2  1975 1975.1 1975.2
# count     195   195    195    195   195    195    195   195    195    195
# unique    127   103     89    115   111     88    117   104     84    115
# top      1.2   0.6    0.4    1.6   0.9    0.2    1.5   0.9    0.2    1.0
# freq        5     8     15      6     9     18      7     7     18      7
#
# [4 rows x 126 columns]

# %% [markdown]
# Tabloda görebileceğiniz gibi, bazı değerler 'No d' olarak yazılmıştır. Bu ifade 'Veri yok', yani eksik veri anlamına gelir. Bu eksik verilerin projemizin bütünlüğü açısından doldurulması gerektiğini düşünsek de, verileri incelediğimizde, tüm eksik verilerin 'Güney Sudan', 'Sudan', 'San Marino've 'Monako' da olduğunu görüyoruz.

# %%
Obesity.loc[['South Sudan', 'Sudan', 'San Marino', 'Monaco']]
# Out:
#               2016 2016.1 2016.2  2015 2015.1 2015.2  2014 2014.1 2014.2  \
# Country Name
# South Sudan   No d   No d   No d  No d   No d   No d  No d   No d   No d
# Sudan         No d   No d   No d  No d   No d   No d  No d   No d   No d
# San Marino    No d   No d   No d  No d   No d   No d  No d   No d   No d
# Monaco        No d   No d   No d  No d   No d   No d  No d   No d   No d
#
#               2013  ... 1978.2  1977 1977.1 1977.2  1976 1976.1 1976.2  1975  \
# Country Name        ...
# South Sudan   No d  ...   No d  No d   No d   No d  No d   No d   No d  No d
# Sudan         No d  ...   No d  No d   No d   No d  No d   No d   No d  No d
# San Marino    No d  ...   No d  No d   No d   No d  No d   No d   No d  No d
# Monaco        No d  ...   No d  No d   No d   No d  No d   No d   No d  No d
#
#              1975.1 1975.2
# Country Name
# South Sudan    No d   No d
# Sudan          No d   No d
# San Marino     No d   No d
# Monaco         No d   No d
#
# [4 rows x 126 columns]

# %% [markdown]
# Bu ülkeleri data setimizden temizledik.

# %%
Obesity.drop('South Sudan', axis = 0, inplace = True)
Obesity.drop('Sudan', axis = 0, inplace = True)
Obesity.drop('San Marino', axis = 0, inplace = True)
Obesity.drop('Monaco', axis = 0, inplace = True)

# %% [markdown]
# Bu işlemlerden sonra ve verilerimizi sayısal değerlere dönüştürdükten sonra, describe komutunu işleterek kontrol edelim.

# %%
dataframes = [Internet_Users, Population, Obesity]

for dataframe in dataframes:
    
    for column in dataframe:
        
        pd.to_numeric(dataframe[column])
    
    
Obesity.describe()
# Out:
#         2016 2016.1 2016.2  2015 2015.1 2015.2  2014 2014.1 2014.2  2013  ...  \
# count    191    191    191   191    191    191   191    191    191   191  ...
# unique   143    136    152   152    139    150   143    134    151   138  ...
# top     23.1   24.2   25.4  24.1   4.3    36.4  19.2   4.1    24.5  19.5  ...
# freq       4      4      4     3      4      3     4      5      3     4  ...
#
#        1978.2  1977 1977.1 1977.2  1976 1976.1 1976.2  1975 1975.1 1975.2
# count     191   191    191    191   191    191    191   191    191    191
# unique    126   102     88    114   110     87    116   103     83    114
# top      1.7   0.6    0.4    1.6   0.9    0.2    1.5   0.9    0.2    1.4
# freq        5     8     15      6     9     18      7     7     18      7
#
# [4 rows x 126 columns]

# %% [markdown]
# Son gördüğümüz tabloya göre, veri setimizde birçok biricik değer var, yani birkaç tekrarlanan değer var. Bu, çalışmalarımızda kullandığımız verilerin ayrıntı seviyelerini ifade eder. Çünkü verilerimizin çoğunun aynı olması, genelleme veya basitleştirme sonucunda verilere ulaşıldığı anlamına gelir.

# %% [markdown]
# Daha önce de belirttiğimiz gibi, cinsiyet değerlerinin projemizdeki verilerle hiçbir ilişkisi olmadığından .1 ve .2 ile biten sütunları temizlememiz gerekiyor.

# %%
for column in Obesity:
    
    # if the penultimate character is '.'
    if Obesity[column].name[-2] == '.':
        # drop this column
        Obesity.drop(column, axis = 1, inplace = True)

# %% [markdown]
# Obezite data frame'inin diğer iki data frame ile karşılaştırmak için sütunların sırasını tersine çevirmemiz gerekir.

# %%
Obesity = Obesity.iloc[:, ::-1]

# %%
Internet_Users.head()
# Out:
#               1975  1976  1977  1978  1979  1980  1981  1982  1983  1984  ...  \
# Country Name                                                              ...
# Aruba          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Afghanistan    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Angola         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Albania        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Andorra        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#                    2007   2008   2009  2010  2011       2012  2013   2014  \
# Country Name
# Aruba         30.900000  52.00  58.00  62.0  69.0  74.000000  78.9  83.78
# Afghanistan    1.900000   1.84   3.55   4.0   5.0   5.454545   5.9   7.00
# Angola         1.700000   1.90   2.30   2.8   3.1   6.500000   8.9  21.40
# Albania       15.036115  23.86  41.20  45.0  49.0  54.655959  57.2  60.10
# Andorra       70.870000  70.04  78.53  81.0  81.0  86.434425  94.0  95.90
#
#                    2015       2016
# Country Name
# Aruba         88.661227  93.542454
# Afghanistan    8.260000  11.200000
# Angola        12.400000  13.000000
# Albania       63.252933  66.363445
# Andorra       96.910000  97.930637
#
# [5 rows x 42 columns]

# %%
Population.head()
# Out:
#                     1975        1976        1977        1978        1979  \
# Country Name
# Aruba            60657.0     60586.0     60366.0     60103.0     59980.0
# Afghanistan   12689160.0  12943093.0  13171306.0  13341198.0  13411056.0
# Angola         7024000.0   7279509.0   7533735.0   7790707.0   8058067.0
# Albania        2404831.0   2458526.0   2513546.0   2566266.0   2617832.0
# Andorra          30705.0     31777.0     32771.0     33737.0     34818.0
#
#                     1980        1981        1982        1983        1984  ...  \
# Country Name                                                              ...
# Aruba            60096.0     60567.0     61345.0     62201.0     62836.0  ...
# Afghanistan   13356511.0  13171673.0  12882528.0  12537730.0  12204292.0  ...
# Angola         8341289.0   8640446.0   8952950.0   9278096.0   9614754.0  ...
# Albania        2671997.0   2726056.0   2784278.0   2843960.0   2904429.0  ...
# Andorra          36067.0     37500.0     39114.0     40867.0     42706.0  ...
#
#                     2007        2008        2009        2010        2011  \
# Country Name
# Aruba           101222.0    101358.0    101455.0    101669.0    102046.0
# Afghanistan   27100536.0  27722276.0  28394813.0  29185507.0  30117413.0
# Angola        20905363.0  21695634.0  22514281.0  23356246.0  24220661.0
# Albania        2970017.0   2947314.0   2927519.0   2913021.0   2905195.0
# Andorra          82684.0     83862.0     84463.0     84449.0     83747.0
#
#                     2012        2013        2014        2015        2016
# Country Name
# Aruba           102560.0    103159.0    103774.0    104341.0    104872.0
# Afghanistan   31161376.0  32269589.0  33370794.0  34413603.0  35383128.0
# Angola        25107931.0  26015780.0  26941779.0  27884381.0  28842484.0
# Albania        2900401.0   2895092.0   2889104.0   2880703.0   2876101.0
# Andorra          82427.0     80774.0     79213.0     78011.0     77297.0
#
# [5 rows x 42 columns]

# %%
Obesity.head()
# Out:
#               1975  1976  1977  1978  1979  1980  1981  1982  1983  1984  ...  \
# Country Name                                                              ...
# Afghanistan   0.5   0.5   0.6   0.6   0.6   0.7   0.7   0.8   0.8   0.9   ...
# Albania       6.5   6.7   6.8   7.0   7.2   7.4   7.6   7.8   8.0   8.3   ...
# Algeria       6.9   7.2   7.4   7.7   8.0   8.3   8.6   9.0   9.4   9.7   ...
# Andorra       12.9  13.5  14.0  14.5  15.0  15.5  16.0  16.5  16.9  17.4  ...
# Angola        0.8   0.9   0.9   1.0   1.1   1.1   1.2   1.3   1.3   1.4   ...
#
#               2007  2008  2009  2010  2011  2012  2013  2014  2015  2016
# Country Name
# Afghanistan   3.4   3.6   3.8   4.0   4.2   4.4   4.7   4.9   5.2   5.5
# Albania       16.5  17.0  17.6  18.2  18.8  19.3  19.9  20.5  21.1  21.7
# Algeria       21.4  22.0  22.7  23.3  24.0  24.7  25.3  26.0  26.7  27.4
# Andorra       23.8  24.0  24.2  24.4  24.6  24.8  25.0  25.2  25.4  25.6
# Angola        5.3   5.6   5.9   6.2   6.5   6.8   7.1   7.5   7.9   8.2
#
# [5 rows x 42 columns]

# %% [markdown]
# Tüm bu öznitelik belirleme işlemlerinden sonra 3 data frame'in tüm özelliklerini aynı hale getirdik.

# %% [markdown]
# ### Ortak Ülkelerin Bulunması

# %% [markdown]
# Obezite data setinde Internet_Users ve Population veri setinden daha az ülkemiz var. Kesişen ülkeler üzerinde ortak bir çalışma yapılabileceğinden, önce kesişen ülkeleri bulmalı ve daha sonra bu ülkeler dışında kalanları tüm data setlerden çıkarmalıyız.

# %%
intersection = np.intersect1d(Internet_Users.index, Obesity.index)
Internet_Users = Internet_Users.loc[intersection]

# %% [markdown]
# Sütun temizleme işleminden sonra, Internet_Users uygulamasının Obesity data frame'ine dahil olan tüm ülkeleri içermediği görülmektedir. Çünkü ülke sayısı sadece kesişen ülkeler alındığında 162 olarak kaldı ve bu sayı Obesity data setindeki ülke sayısı olan 195ten az.
#
# Bu durumda, yalnızca Internet_Users ve Population'dan değil, aynı zamanda Obesity data frame'inden kesişen ülkeleri çıkarmamız gerekir.

# %%
# yukarıdaki kesişimi tanımladık

Population = Population.loc[intersection]

# %%
# yukarıdaki kesişimi tanımladık

Obesity = Obesity.loc[intersection]

# %%
print('Shape of Internet_Users:', Internet_Users.shape)
print('Shape of Population:', Population.shape)
print('Shape of Obesity:', Obesity.shape)
# Out:
# Shape of Internet_Users: (162, 42)
# Shape of Population: (162, 42)
# Shape of Obesity: (162, 42)

# %% [markdown]
# Yukarıdaki çıktıdan da görülebileceği gibi, artık aynı ülkelerden aynı yıllara ait data framelerinde 3 farklı veri bulabiliriz.

# %% [markdown]
# ### Kayıp Değerler

# %% [markdown]
# **Internet_Users** 'ın eksik değerlerine bakalım. 20'den az girdisi olan ülkeleri bulalım.

# %%
there_is_missing_value = False

row_names = []

countries_dict = {}

for index, row in Internet_Users.iterrows():
    
    if row.count() < 20:
        
        there_is_missing_value = True
        
        row_names.append(row.name)
        countries_dict[row.name] = row.count()
        
        #print(row.name , row.count())

        
if there_is_missing_value == False:
    
    print('There is no missing value!')
    
else :        
          
    lists = sorted(countries_dict.items())
    x, y = zip(*lists)    # unpack a list of pairs into two tuples

    fig = plt.figure(figsize=(10, 6), dpi= 80, facecolor='w', edgecolor='k')

    plt.bar(row_names,  y, color = "tab:cyan")
    plt.title('  Interner User\'ın Ülkelerinin Kayıp Değer Sayıları \n',fontsize=27)
    plt.xlabel('\nÜlkeler',fontsize=20)
    plt.ylabel('Kayıp değerlerin sayısı\n',fontsize=20)    

    plt.ylim(0,25)
    plt.xticks(rotation=90, fontsize=12)
    plt.yticks(fontsize=10)
    plt.show()

# %% [markdown]
# Bu sütunlara bakalım.

# %%
Internet_Users.loc[row_names,:]
# Out:
#               1975  1976  1977  1978  1979  1980  1981  1982  1983  1984  ...  \
# Country Name                                                              ...
# Afghanistan    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Bhutan         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Guyana         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Iraq           NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Liberia        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Libya          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Mongolia       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Montenegro     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Myanmar        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Nauru          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Palau          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Serbia         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Tajikistan     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Timor-Leste    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Turkmenistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Tuvalu         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#                    2007   2008   2009   2010       2011       2012       2013  \
# Country Name
# Afghanistan    1.900000   1.84   3.55   4.00   5.000000   5.454545   5.900000
# Bhutan         5.920000   6.55   7.17  13.60  14.400000  15.600000  22.400000
# Guyana        13.800000  18.20  23.90  29.90  30.000000  30.500000  31.000000
# Iraq           0.930000   1.00   1.06   2.50   5.000000   7.100000   9.200000
# Liberia        0.551377   0.53   2.00   2.30   2.500000   2.600000   3.200000
# Libya          4.721999   9.00  10.80  14.00  14.000000        NaN  16.500000
# Mongolia       9.000000   9.80  10.00  10.20  12.499991  16.400000  17.699984
# Montenegro    30.800000  32.90  35.10  37.50  35.611541  56.838783  60.310000
# Myanmar        0.217128   0.22   0.22   0.25   0.980000   4.000000   8.000000
# Nauru               NaN    NaN    NaN    NaN  54.000000        NaN        NaN
# Palau               NaN    NaN    NaN    NaN        NaN        NaN        NaN
# Serbia        33.150000  35.60  38.10  40.90  42.200000  48.100000  53.450364
# Tajikistan     7.197620   8.78  10.07  11.55  13.030000  14.510000  16.000000
# Timor-Leste    1.000000   1.50   2.00   3.00   4.000000   7.000000  11.000000
# Turkmenistan   1.406361   1.75   1.95   3.00   5.000000   7.195800   9.600000
# Tuvalu        10.000000  15.00  20.00  25.00  30.000000  35.000000  37.000000
#
#                    2014       2015       2016
# Country Name
# Afghanistan    7.000000   8.260000  11.200000
# Bhutan        30.300000  39.800000  41.772645
# Guyana        32.000000  34.000000  35.660000
# Iraq          13.210000  58.000000  21.230000
# Liberia        5.410000  33.000000   7.319106
# Libya         17.760000  19.016080  20.272160
# Mongolia      19.942447  22.500004  22.265770
# Montenegro    61.000000  68.119581  69.881647
# Myanmar       11.520000  21.725834  25.073304
# Nauru               NaN        NaN        NaN
# Palau               NaN        NaN        NaN
# Serbia        62.075080  65.317025  67.056841
# Tajikistan    17.490000  18.980000  20.470000
# Timor-Leste   17.500000  23.000000  25.246250
# Turkmenistan  12.200000  14.996775  17.990324
# Tuvalu        39.200000  42.700000  46.009152
#
# [16 rows x 42 columns]

# %% [markdown]
# Bu çıktıdan da görülebileceği gibi, internet 2003'ten önce Karadağ'da kullanılmamıştır. İnternet kullanım verileri 2003 yılından bu yana tüm yıllarda olduğu için bu ülkeyi data framelerimizden çıkarmaya gerek yoktur.
#
# 20'den az girdisi olan ülkelere sırayla baktığımızda, sadece iki ülkenin verilerinin (Nauru ve Palau) rastgele girildiğini görüyoruz.
#
# Bu durumda, bu iki ülkeyi tüm data setlerimizden çıkarmamız gerekiyor.

# %%
dataframes = [Internet_Users, Population, Obesity]

for dataframe in dataframes:

    dataframe.drop('Nauru', axis = 0, inplace = True)
    dataframe.drop('Palau', axis = 0, inplace = True)

# %% [markdown]
# **Population**'ın kayıp değer sayısına bakalım ve 42 yıl içinde kayıp yıl var mı inceleyelim.

# %%
there_is_missing_value = False
row_names = []

countries_dict = {}

for index, row in Population.iterrows():
    
    if row.count() < 42:
        
        there_is_missing_value = True
        
        row_names.append(row.name)
        countries_dict[row.name] = row.count()
        
        #print(row.name , row.count())

        
if there_is_missing_value == False:
    
    print('There is no missing value!')
    
else :        
          
    lists = sorted(countries_dict.items())
    x, y = zip(*lists)    # unpack a list of pairs into two tuples

    fig = plt.figure(figsize=(6, 6), dpi= 80, facecolor='w', edgecolor='k')

    plt.bar(row_names,  y, color = "plum")
    plt.title('  Population\'ın Ülkelerinin Kayıp Değer Sayısı \n',fontsize=20)
    plt.xlabel('\nÜlkeler',fontsize=15)
    plt.ylabel('Kayıp Değer Sayısı\n',fontsize=15)    

    plt.ylim(0,42)
    plt.xticks(rotation=90, fontsize=12)
    plt.yticks(fontsize=10)
    plt.show()

# %% [markdown]
# Bu sütunları inceleyelim.

# %%
Population.loc[row_names,:]
# Out:
#                    1975       1976       1977       1978       1979  \
# Country Name
# Eritrea       1505439.0  1547975.0  1591620.0  1636769.0  1683939.0
# Kuwait        1021720.0  1085861.0  1153583.0  1224067.0  1296081.0
# Serbia              NaN        NaN        NaN        NaN        NaN
#
#                    1980       1981       1982       1983       1984  ...  \
# Country Name                                                         ...
# Eritrea       1733416.0  1784561.0  1836823.0  1890558.0  1946305.0  ...
# Kuwait        1368677.0  1439331.0  1507645.0  1576968.0  1652150.0  ...
# Serbia              NaN        NaN        NaN        NaN        NaN  ...
#
#                    2007       2008       2009       2010       2011  \
# Country Name
# Eritrea       2996536.0  3062779.0  3119920.0  3170435.0  3213972.0
# Kuwait        2504019.0  2656009.0  2821045.0  2991884.0  3168060.0
# Serbia        7381579.0  7350222.0  7320807.0  7291436.0  7234099.0
#
#                    2012       2013       2014       2015       2016
# Country Name
# Eritrea             NaN        NaN        NaN        NaN        NaN
# Kuwait        3348853.0  3526378.0  3690942.0  3835591.0  3956873.0
# Serbia        7199077.0  7164132.0  7130576.0  7095383.0  7058322.0
#
# [3 rows x 42 columns]

# %% [markdown]
# **Population** data frame'inde kayıp değer düzenleme konusunda karar verebilmek için bu 3 ülkeden daha fazla bilgi toplamalıyız.

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18,6))
years = np.array(list(range(1975,2017)))

Population.columns = pd.to_numeric(Population.columns)

Eritrea = Population.loc[row_names[0],:]
Kuwait = Population.loc[row_names[1],:]
Serbia = Population.loc[row_names[2],:]

sns.regplot(x = years, y = Eritrea, data = Population, marker='o', ax=axes[0])
sns.regplot(x = years, y = Kuwait, data = Population, marker='o', ax=axes[1])
sns.regplot(x = years, y = Serbia, data = Population, marker='o', ax=axes[2])

fig.tight_layout(pad=3.0)

plt.show()

# %% [markdown]
# Eritrea grafiğine dayanarak, eksik değerleri doldurmak için parçalı bir polinom enterpolasyonu ile segment bazında enterpolasyon yapmaya karar verdik.

# %%
Eritrea.interpolate(method = 'spline', order = 1, limit_direction = 'forward', axis = 0, inplace = True)

Population.loc[row_names[0],:] = Eritrea

sns.regplot(x = years, y = Eritrea, data = Population, marker='o')

plt.show()

# %% [markdown]
# Eritrea grafiğine dayanarak, eksik değerleri doldurmak için polinom enterpolasyonunu kullanmalıyız.

# %%
#Population.loc[row_names[1],:].index = pd.to_numeric(Population.loc[row_names[1],:].index)

Kuwait.interpolate(method = 'polynomial', order = 3, limit_direction = 'forward', axis = 0, inplace = True)

Population.loc[row_names[1],:] = Kuwait

sns.regplot(x = years, y = Kuwait, data = Population, marker='o')

plt.show()

# %% [markdown]
# Sırbistan 2006'da kurulduğundan 2006'dan önceki nüfus bilgilerini 0 ile dolduruyoruz.

# %% [markdown]
# **Population**'ın kayıp değer sayısına bakalım ve 42 yıl içinde kayıp yıl var mı inceleyelim.

# %%
there_is_missing_value = False

for index, row in Obesity.iterrows():
    if row.count() < 42:
        there_is_missing_value = True
        print(row.name, row.count())
        
if there_is_missing_value == False:
    print('Kayıp değer yok!')
# Out:
# Kayıp değer yok!

# %% [markdown]
# Obesity data setinde kayıp değer yok.

# %% [markdown]
# Data setindeki NaN değerlerine sahip İnternet kullanıcılarının hücrelerine bakarsak, internetin o yıllarda kullanılmadığını anlıyoruz. Böylece bu NaN değerlerini sıfır değerleriyle değiştirebiliriz.

# %% [markdown]
# Enterpolasyon yöntemleri ile doldurulması gereken eksik değerleri doldurduğumuz veya sildiğimiz veya tüm data framelerin kaldırdığımız için, kalan eksik değerleri sıfırla doldurabiliriz.

# %%
Internet_Users = Internet_Users.fillna(0)

Population = Population.fillna(0)

# Obesity data setinde NaN olmadığı için değişiklik yapmıyoruz.

# %% [markdown]
# ### Aykırı Değerlerin İdaresi

# %% [markdown]
# 2016 yılına kadar nüfusu 100.000'i aşmayan ülkelere baktığımızda, bu ülkelerin yeni kurulduğu, daha az gelişmiş veya dağıldığı için bu ülkelerin çalışmamıza aykırı değerler barındırdığını düşünüyoruz.

# %% [markdown]
# Hangi ülkelerin kaç yıl boyunca 100.000 nüfus sınırının altında olduğuna bakalım.

# %%
less_than_100000 = {}

for index, row in Population.iterrows():
   
    counter = 0
    for column in Population.columns:
            
        if row[column] < 100000 :
            counter = counter + 1
            less_than_100000[index] = counter
            
        
    if index in less_than_100000.keys():
        print(less_than_100000[index],"yıl boyunca,", index, "100000 limitini aşamamıştır.")
# Out:
# 42 yıl boyunca, Andorra  100000 limitini aşamamıştır.
# 42 yıl boyunca, Antigua and Barbuda  100000 limitini aşamamıştır.
# 42 yıl boyunca, Dominica  100000 limitini aşamamıştır.
# 19 yıl boyunca, Grenada  100000 limitini aşamamıştır.
# 34 yıl boyunca, Kiribati  100000 limitini aşamamıştır.
# 42 yıl boyunca, Marshall Islands  100000 limitini aşamamıştır.
# 8 yıl boyunca, Sao Tome and Principe  100000 limitini aşamamıştır.
# 15 yıl boyunca, Serbia  100000 limitini aşamamıştır.
# 42 yıl boyunca, Seychelles  100000 limitini aşamamıştır.
# 29 yıl boyunca, Tonga  100000 limitini aşamamıştır.
# 42 yıl boyunca, Tuvalu  100000 limitini aşamamıştır.
# 1 yıl boyunca, Vanuatu  100000 limitini aşamamıştır.

# %% [markdown]
# Hangi ülkelerin sınırın altında olduğunu daha iyi görmek için bir çubuk diyagram çizelim.

# %%
lists = sorted(less_than_100000.items())
x, y = zip(*lists)    # unpack a list of pairs into two tuples

limit_line = [15,15,15,15,15,15,15,15,15,15,15,15]

fig = plt.figure(figsize=(10, 6), dpi= 80, facecolor='w', edgecolor='k')

plt.plot(x, limit_line, color = "royalblue")

plt.bar(x,  y, color = "salmon")
plt.title('  Ülkeler ve Kaç Kere Sınırın Altında Kaldıkları \n',fontsize=27)
plt.xlabel('\nÜlkeler',fontsize=20)
plt.ylabel('Kaç kere sınır altında kaldı\n',fontsize=20)    

plt.ylim(0,50)
plt.xticks(rotation=90, fontsize=12)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# Grafikte göreceğimiz gibi isimleri Sao Tome and Principe, Sırbistan, Vanuatu olan 3 ülke sınırımızın altında. Dolayısıyla, bu ülkeler projemize aykırı değerler barındırdığı için, bu ülkeleri 3 data setten de kaldırmalıyız.

# %%
dataframes = [Internet_Users, Population, Obesity]

for dataframe in dataframes:

    dataframe.drop('Sao Tome and Principe', axis = 0, inplace = True)
    dataframe.drop('Serbia', axis = 0, inplace = True)
    dataframe.drop('Vanuatu', axis = 0, inplace = True)

# %%
print('Internet_Users Satır ve Sütun sayısı:', Internet_Users.shape)
print('Population Satır ve Sütun sayısı:', Population.shape)
print('Obesity Satır ve Sütun sayısı:', Obesity.shape)
# Out:
# Internet_Users Satır ve Sütun sayısı: (157, 42)
# Population Satır ve Sütun sayısı: (157, 42)
# Obesity Satır ve Sütun sayısı: (157, 42)

# %% [markdown]
# ## Modelleme<a class="anchor" id="modeling"></a>

# %% [markdown]
# Basit doğrusal regresyon modeli kullanılacaktır. Çünkü verilerimiz doğrusal olarak büyüyor. Parametreler İnternet Kullanıcıları ve Obezitedir. İnternet Kullanıcılarının ve Obezitenin doğrusal olarak bağımlı olduğunu görmeyi ve modelimizi test etmeyi istiyoruz.

# %%
lm=LinearRegression()

# %%
X=np.array(Internet_Users.iloc[147,:]).reshape(-1, 1)

# %%
Y=np.array(Obesity.iloc[147,:]).reshape(-1, 1)

# %%
X = X.astype(float)    
Y = Y.astype(float)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, train_size = 0.7, test_size = 0.3, random_state = 0)

#print ("X_train: ", X_train)
#print ("y_train: ", y_train)
#print("X_test: ", X_test)
#print ("y_test: ", y_test)

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ## Değerlendirme<a class="anchor" id="evaluation"></a>

# %%
y_predicted = lm.predict(X_test)

r_sq = lm.score(y_predicted, y_test)
mse = mean_squared_error(y_predicted, y_test) 

print('R-squared Error:', r_sq)
print('Mean Squared Error:', mse)
# Out:
# R-squared Error: 0.40133086667949325
# Mean Squared Error: 15.634479348682284

# %% [markdown]
# score() fonksiyonu R kare hatasını hesaplar ve mean_squared_error() fonksiyonu ortalama kare hatasını hesaplar. Gördüğümüz gibi, Türkiye ile ilgili çalışmamızda tahminimizin hata sayıları yüksektir. Nedenini bulmak için bir regresyon grafiği çizelim.

# %% [markdown]
# Katsayı tahmini için bir fonksiyon.

# %%
def estimate_coef(x, y): 
    # number of observations/points 
    n = np.size(x) 
  
    # mean of x and y vector 
    m_x, m_y = np.mean(x), np.mean(y) 
  
    # calculating cross-deviation and deviation about x 
    SS_xy = np.sum(y*x) - n*m_y*m_x 
    SS_xx = np.sum(x*x) - n*m_x*m_x 
  
    # calculating regression coefficients 
    b_1 = SS_xy / SS_xx 
    b_0 = m_y - b_1*m_x 
  
    return(b_0, b_1)

# %% [markdown]
# Gerçek veri noktaları için özelleşmiş regresyon çizgisi çizme fonksiyonu.

# %%
def plot_regression_line(x, y, b): 
    
    fig = plt.figure(figsize=(10, 6), dpi= 80, facecolor='w', edgecolor='k')
    
    # plotting the actual points as scatter plot 
    plt.scatter(x, y, color = "m", marker = "o", s = 40) 
  
    # predicted response vector 
    y_pred = b[0] + b[1]*x 
  
    # plotting the regression line 
    plt.plot(x, y_pred, color = "g") 
  
    # putting labels 
    plt.title('Regression Line and Actual Data Points\n', fontsize = 15)
    plt.xlabel('Internet Use ratio') 
    plt.ylabel('Obesity ratio') 
  
    # function to show plot 
    plt.show()

# %% [markdown]
# Hata değerinin neden yüksek olduğunu anlamak için regresyon grafiğini çizelim.

# %%
b = estimate_coef(X, Y) 
print("Estimated coefficients:\nb0 = {}  \nb1 = {}".format(b[0], b[1])) 
  
# plotting regression line 
plot_regression_line(X, Y, b)
# Out:
# Estimated coefficients:
# b0 = 15.557288285637858
# b1 = 0.32729012115345374

# %% [markdown]
# Çizdiğimiz grafiğe bakarsak, internetin kullanılmadığı dönemler tahminlerimizi büyük ölçüde etkilemiş. Şimdi bu parçaları çıkartalım ve tekrar bir grafik çizelim.

# %%
fig = plt.figure(figsize=(10, 6), dpi= 80, facecolor='w', edgecolor='k')
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes

ax.plot(years.reshape(-1, 1), np.transpose(np.array(Internet_Users.iloc[147,:])), color='lightcoral', linewidth=4)


ax.set_title('Turkey\n', fontsize = 20)
ax.set_xticks(years)
ax.set_xticklabels(years, rotation = 90)

plt.xlabel('\nYears') 
plt.ylabel('Internet Use ratio') 

plt.show()

# %% [markdown]
# Şimdi 1997'den sonraki verilerle tekrar doğrusal regresyon modelimizi oluşturalım.

# %%
lm_2 = LinearRegression()

X = np.array(Internet_Users.iloc[147,23:]).reshape(-1, 1)
Y = np.array(Obesity.iloc[147,23:]).reshape(-1, 1)

X = X.astype(float)    
Y = Y.astype(float)

X_train, X_test, y_train, y_test = train_test_split(X, Y, train_size = 0.7, test_size = 0.3, random_state = 0)

lm_2.fit(X_train,y_train)

y_predicted = lm_2.predict(X_test)

r_sq = lm_2.score(y_predicted, y_test)
mse = mean_squared_error(y_predicted, y_test) 

print('R-squared Error:', r_sq)
print('Mean Squared Error:', mse)

b = estimate_coef(X, Y) 
print("\nEstimated coefficients:\nb_0 = {}  \nb_1 = {}".format(b[0], b[1])) 
  
# plotting regression line 
plot_regression_line(X, Y, b)
# Out:
# R-squared Error: 0.18459442844110108
# Mean Squared Error: 0.2654446223533438
#
# Estimated coefficients:
# b_0 = 21.527651866548496
# b_1 = 0.1787385456221154

# %% [markdown]
# R-kare Hatamız 0.18 ve Ortalama Kare Hatamız 0.26'dır. Bu, modelimizin verilerimize uygun olduğu anlamına gelir!

# %% [markdown]
# ## Referanslar<a class="anchor" id="references"></a>

# %% [markdown]
# * Doğrusal Regresyon Uygulaması
#
#     https://www.geeksforgeeks.org/linear-regression-python-implementation/
#
#
# * Internet Users Veriseti
#
#     https://data.worldbank.org/indicator/IT.NET.USER.ZS
#
#
# * Population Veriseti
#
#     https://data.worldbank.org/indicator/sp.pop.totl
#
#
# * Obesity Veriseti
#
#     https://apps.who.int/gho/data/node.main.A900A?lang=en

# %% [markdown]
# **Disclaimer!** <font color='grey'>This notebook was prepared by Gizem Kaya and Necdet Alperen Özil as a term project for the *BBM469 - Data Intensive Applications Laboratory* class. The notebook is available for educational purposes only. There is no guarantee on the correctness of the content provided as it is a student work.
#
# If you think there is any copyright violation, please let us [know](https://forms.gle/BNNRB2kR8ZHVEREq8).
# </font>
